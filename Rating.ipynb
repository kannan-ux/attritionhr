# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\sakth\Downloads\Employee-Attrition - Employee-Attrition.csv")
import warnings
warnings.filterwarnings("ignore")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df1=df[['Education','JobInvolvement','JobLevel','MonthlyIncome','YearsAtCompany','YearsInCurrentRole','PerformanceRating']]

# %%
df1
# Out:
#       Education  JobInvolvement  JobLevel  MonthlyIncome  YearsAtCompany  \
# 0             2               3         2           5993               6
# 1             1               2         2           5130              10
# 2             2               2         1           2090               0
# 3             4               3         1           2909               8
# 4             1               3         1           3468               2
# ...         ...             ...       ...            ...             ...
# 1465          2               4         2           2571               5
# 1466          1               2         3           9991               7
# 1467          3               4         2           6142               6
# 1468          3               2         2           5390               9
# 1469          3               4         2           4404               4
#
#       YearsInCurrentRole  PerformanceRating
# 0                      4                  3
# ...

# %%
df1.isnull().sum()
# Out:
# Education             0
# JobInvolvement        0
# JobLevel              0
# MonthlyIncome         0
# YearsAtCompany        0
# YearsInCurrentRole    0
# PerformanceRating     0
# dtype: int64

# %%
X=df1[['Education',	'JobInvolvement',	'JobLevel',	'MonthlyIncome',	'YearsAtCompany',	'YearsInCurrentRole']]

# %%
import seaborn as sns
sns.boxplot(X['YearsInCurrentRole'])
# Out:
# <Axes: ylabel='YearsInCurrentRole'>

# %%
import numpy as np
Q1=X['MonthlyIncome'].quantile(0.25)
Q3=X['MonthlyIncome'].quantile(0.75)
IQR=Q3-Q1
medians=X['MonthlyIncome'].median()
upper_bound=Q3+1.5*IQR
lower_bound=Q1-1.5*IQR
X['MonthlyIncome']=np.where((X['MonthlyIncome']>upper_bound)|(X['MonthlyIncome']<lower_bound),medians,X['MonthlyIncome'])

# %%
sns.boxplot(X['MonthlyIncome'])
# Out:
# <Axes: ylabel='MonthlyIncome'>

# %%
import numpy as np
Q1=X['YearsAtCompany'].quantile(0.25)
Q3=X['YearsAtCompany'].quantile(0.75)
IQR=Q3-Q1
medians=X['YearsAtCompany'].median()
upper_bound=Q3+1.5*IQR
lower_bound=Q1-1.5*IQR
X['YearsAtCompany']=np.where((X['YearsAtCompany']>upper_bound)|(X['YearsAtCompany']<lower_bound),medians,X['YearsAtCompany'])

# %%
sns.boxplot(X['YearsAtCompany'])
# Out:
# <Axes: ylabel='YearsAtCompany'>

# %%
import numpy as np
Q1=X['YearsInCurrentRole'].quantile(0.25)
Q3=X['YearsInCurrentRole'].quantile(0.75)
IQR=Q3-Q1
medians=X['YearsInCurrentRole'].median()
upper_bound=Q3+1.5*IQR
lower_bound=Q1-1.5*IQR
X['YearsInCurrentRole']=np.where((X['YearsInCurrentRole']>upper_bound)|(X['YearsInCurrentRole']<lower_bound),medians,X['YearsInCurrentRole'])

# %%
sns.boxplot(X['YearsInCurrentRole'])
# Out:
# <Axes: ylabel='YearsInCurrentRole'>

# %%
X
# Out:
#       Education  JobInvolvement  JobLevel  MonthlyIncome  YearsAtCompany  \
# 0             2               3         2       5993.000             6.0
# 1             1               2         2       5130.000            10.0
# 2             2               2         1       2090.000             0.0
# 3             4               3         1       2909.000             8.0
# 4             1               3         1       3468.000             2.0
# ...         ...             ...       ...            ...             ...
# 1465          2               4         2       2571.000             5.0
# 1466          1               2         3       4909.375             7.0
# 1467          3               4         2       6142.000             6.0
# 1468          3               2         2       5390.000             9.0
# 1469          3               4         2       4404.000             4.0
#
#       YearsInCurrentRole
# 0                    4.0
# 1                    7.0
# ...

# %%
X['MonthlyIncome']=X['MonthlyIncome'].astype("int")

# %%
X['YearsAtCompany']=X['YearsAtCompany'].astype("int")

# %%
X['YearsInCurrentRole']=X['YearsInCurrentRole'].astype("int")

# %%
X
# Out:
#       Education  JobInvolvement  JobLevel  MonthlyIncome  YearsAtCompany  \
# 0             2               3         2           5993               6
# 1             1               2         2           5130              10
# 2             2               2         1           2090               0
# 3             4               3         1           2909               8
# 4             1               3         1           3468               2
# ...         ...             ...       ...            ...             ...
# 1465          2               4         2           2571               5
# 1466          1               2         3           4909               7
# 1467          3               4         2           6142               6
# 1468          3               2         2           5390               9
# 1469          3               4         2           4404               4
#
#       YearsInCurrentRole
# 0                      4
# 1                      7
# ...

# %%
Y=df1[['PerformanceRating']]

# %%
Y.value_counts()
# Out:
# PerformanceRating
# 3                    1244
# 4                     226
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#       Education  JobInvolvement  JobLevel  MonthlyIncome  YearsAtCompany  \
# 1097          2               2         1           2296               1
# 727           2               3         1           1051               0
# 254           2               3         2           6931               3
# 1175          3               3         2           5295               5
# 1341          3               3         2           4197              10
# ...         ...             ...       ...            ...             ...
# 1130          3               4         2           3407              10
# 1294          3               4         2           6870               3
# 860           4               2         1           2853               0
# 1459          2               2         2           4025               4
# 1126          3               3         5           4919               1
#
#       YearsInCurrentRole
# 1097                   1
# 727                    0
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

le=LogisticRegression()
re=RandomForestClassifier()

# %%
re.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred=re.predict(X_test)

# %%
from sklearn.metrics import classification_report
fulreport=classification_report(Y_test,Y_pred)

# %%
print(fulreport)
# Out:
#               precision    recall  f1-score   support
#
#            3       0.86      0.97      0.91       251
#            4       0.20      0.05      0.08        43
#
#     accuracy                           0.83       294
#    macro avg       0.53      0.51      0.49       294
# weighted avg       0.76      0.83      0.79       294

# %%
import numpy as np
inputdata=(3	,4	,2	,6142,	6	,2)
inputarray=np.asarray(inputdata)
inputreshape=inputarray.reshape(1,-1)
prediction=re.predict(inputreshape)
print(*prediction)
# Out:
# 4

# %%
import pickle
with open('rating.pkl','wb')as file:
    pickle.dump(re,file)

# %%
print(type(re))
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
