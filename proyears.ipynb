# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\sakth\Downloads\Employee-Attrition - Employee-Attrition.csv")
import warnings
warnings.filterwarnings("ignore")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df1=df[['JobLevel','TotalWorkingYears','YearsInCurrentRole','PerformanceRating','Education','YearsSinceLastPromotion']]

# %%
df1
# Out:
#       JobLevel  TotalWorkingYears  YearsInCurrentRole  PerformanceRating  \
# 0            2                  8                   4                  3
# 1            2                 10                   7                  4
# 2            1                  7                   0                  3
# 3            1                  8                   7                  3
# 4            1                  6                   2                  3
# ...        ...                ...                 ...                ...
# 1465         2                 17                   2                  3
# 1466         3                  9                   7                  3
# 1467         2                  6                   2                  4
# 1468         2                 17                   6                  3
# 1469         2                  6                   3                  3
#
#       Education  YearsSinceLastPromotion
# 0             2                        0
# ...

# %%
df1.isnull().sum()
# Out:
# JobLevel                   0
# TotalWorkingYears          0
# YearsInCurrentRole         0
# PerformanceRating          0
# Education                  0
# YearsSinceLastPromotion    0
# dtype: int64

# %%
# import numpy as np
# Q1=df1['TotalWorkingYears'].quantile(0.25)
# Q3=df1['TotalWorkingYears'].quantile(0.75)
# IQR=Q3-Q1
# upper_bound=Q3+1.5*IQR
# lower_bound=Q1-1.5*IQR
# meadians=df1['TotalWorkingYears'].median()
# df1['TotalWorkingYears']=np.where((df1['TotalWorkingYears']>upper_bound)|(df1['TotalWorkingYears']<lower_bound),meadians,df1['TotalWorkingYears'])

# %%
# import numpy as np
# Q1=df1['YearsInCurrentRole'].quantile(0.25)
# Q3=df1['YearsInCurrentRole'].quantile(0.75)
# IQR=Q3-Q1
# upper_bound=Q3+1.5*IQR
# lower_bound=Q1-1.5*IQR
# meadians=df1['YearsInCurrentRole'].median()
# df1['YearsInCurrentRole']=np.where((df1['YearsInCurrentRole']>upper_bound)|(df1['YearsInCurrentRole']<lower_bound),meadians,df1['YearsInCurrentRole'])

# %%
# import numpy as np
# Q1=df1['YearsSinceLastPromotion'].quantile(0.25)
# Q3=df1['YearsSinceLastPromotion'].quantile(0.75)
# IQR=Q3-Q1
# upper_bound=Q3+1.5*IQR
# lower_bound=Q1-1.5*IQR
# meadians=df1['YearsSinceLastPromotion'].median()
# df1['YearsSinceLastPromotion']=np.where((df1['YearsSinceLastPromotion']>upper_bound)|(df1['YearsSinceLastPromotion']<lower_bound),meadians,df1['YearsSinceLastPromotion'])

# %%
X=df1[['JobLevel',	'TotalWorkingYears',	'YearsInCurrentRole',	'PerformanceRating',	'Education']]

# %%
df1['YearsSinceLastPromotion']=df1['YearsSinceLastPromotion'].astype("int")

# %%
Y=df1['YearsSinceLastPromotion'].value_counts()
Y
# Out:
# YearsSinceLastPromotion
# 0     581
# 1     357
# 2     159
# 7      76
# 4      61
# 3      52
# 5      45
# 6      32
# 11     24
# 8      18
# 9      17
# 15     13
# 13     10
# 12     10
# 14      9
# 10      6
# Name: count, dtype: int64

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
X = df1[['JobLevel', 'TotalWorkingYears', 'YearsInCurrentRole', 'PerformanceRating', 'Education']]
y = df1['YearsSinceLastPromotion']  
print("Class Distribution Before SMOTE:\n", y.value_counts())
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)
balanced_df = pd.DataFrame(X_resampled, columns=X.columns)
balanced_df['YearsSinceLastPromotion'] = y_resampled
print("Class Distribution After SMOTE:\n", balanced_df['YearsSinceLastPromotion'].value_counts())
# Out:
# Class Distribution Before SMOTE:
#  YearsSinceLastPromotion
# 0     581
# 1     357
# 2     159
# 7      76
# 4      61
# 3      52
# 5      45
# 6      32
# 11     24
# 8      18
# 9      17
# 15     13
# 13     10
# 12     10
# 14      9
# 10      6
# Name: count, dtype: int64
# Class Distribution After SMOTE:
#  YearsSinceLastPromotion
# 0     581
# 1     581
# 3     581
# 2     581
# 7     581
# 4     581
# 8     581
# 6     581
# 5     581
# 15    581
# 9     581
# 13    581
# 12    581
# 10    581
# 11    581
# 14    581
# Name: count, dtype: int64

# %%
X_resampled
# Out:
#       JobLevel  TotalWorkingYears  YearsInCurrentRole  PerformanceRating  \
# 0            2                  8                   4                  3
# 1            2                 10                   7                  4
# 2            1                  7                   0                  3
# 3            1                  8                   7                  3
# 4            1                  6                   2                  3
# ...        ...                ...                 ...                ...
# 9291         3                 20                  14                  3
# 9292         4                 28                  12                  3
# 9293         4                 22                  15                  3
# 9294         3                 23                   7                  3
# 9295         3                 23                  13                  3
#
#       Education
# 0             2
# 1             1
# 2             2
# 3             4
# ...

# %%
X_resampled['TotalWorkingYears']=X_resampled['TotalWorkingYears'].astype("int")

# %%
X_resampled['YearsInCurrentRole']=X_resampled['YearsInCurrentRole'].astype("int")

# %%
from sklearn.model_selection import train_test_split
X_resampled_train,X_resampled_test,y_resampled_train,y_resampled_test=train_test_split(X_resampled,y_resampled,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from xgboost import XGBClassifier,XGBRegressor

de=DecisionTreeRegressor()

# %%
de.fit(X_resampled,y_resampled)
# Out:
# DecisionTreeRegressor()

# %%
ypred=de.predict(X_resampled_test)

# %%
from sklearn.metrics import classification_report,r2_score
fulreport=r2_score(ypred,y_resampled_test)

# %%
print(fulreport)
# Out:
# 0.8441921722384611

# %%
import numpy as np
inputdata=(2,	17,	2,	3,	2)
inputdataarray=np.asarray(inputdata)
inputreshape=inputdataarray.reshape(1,-1)
prediction=de.predict((inputreshape)).astype("int")
print(*prediction)
# Out:
# 0

# %%
import pickle
with open("promotion.pkl","wb")as file:
    pickle.dump(de,file)

# %%
type(de)
# Out:
# sklearn.tree._classes.DecisionTreeRegressor
